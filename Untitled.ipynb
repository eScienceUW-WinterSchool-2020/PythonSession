# %%
import lxml.html as LH
import requests
import pandas as pd
def text(elt):
    return elt.text_content().replace(u'\xa0', u' ')

url = 'https://en.wikipedia.org/wiki/Democracy_Index'
r = requests.get(url)
root = LH.fromstring(r.content)

for table in root.xpath('//*[@id="mw-content-text"]/div[1]/table[2]'):
    header = [text(th) for th in table.xpath('//th')]        # 1
    data = [[text(td) for td in tr.xpath('td')]  
            for tr in table.xpath('//tr')]                   # 2
    data = [row for row in data if len(row)==len(header)]    # 3 
    data = pd.DataFrame(data, columns=header)                # 4

# %%
data
# Out:
# Empty DataFrame
# Columns: [Democracy,
# Types,
# Related topics, Rank
# , Country
# , Score
# , Electoral processand pluralism
# , Functio­ning ofgovern­ment
# , Politicalpartici­pation
# , Politicalculture
# , Civilliberties
# , Regimetype
# , Region[n 1]
# , Changes fromlast year
# , Rank
# , Country
# , Score
# , Electoral processand pluralism
# , Functio­ning ofgovern­ment
# , Politicalpartici­pation
# , Politicalculture
# , Civilliberties
# , Regimetype
# , Region
# , Changes fromlast year
# , Type of regime
# , Score (s)
# , Number ofcountries
# , Percentage ofcountries
# , Percentage ofworld population
# , Rank
# , Region
# , Countries
# , 2006[4]
# , 2008[15]
# , 2010[3]
# , 2011[16]
# , 2012[2]
# , 2013[17]
# , 2014[18]
# , 2015[6]
# , 2016[19]
# , 2017[20]
# , 2018[14]
# , 2019[7]
# , vteLists of countries by political rankings, Freedom, Corruption, Competitiveness, History, Rights, Other]
# Index: []
#
# [0 rows x 52 columns]
